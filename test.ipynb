# %%
import sys

import ngeht_predictions
import matplotlib.pyplot as plt

# %%
ngeht = ngeht_predictions.load(uvfits='/Volumes/GalagaResearch/Developer/blackholes/coreshift_practice/coreshift/SR1_3C279_2017_101_hi_hops_netcal_StokesI.uvfits', scans=True)
ngeht.load_uvfits()
# Out:
# Loading uvfits:  /Volumes/GalagaResearch/Developer/blackholes/coreshift_practice/coreshift/SR1_3C279_2017_101_hi_hops_netcal_StokesI.uvfits
# no IF in uvfits header!
# POLREP_UVFITS: circ
# Number of uvfits Correlation Products: 4
# No NX table in uvfits!
# /Users/galagabits/miniconda3/envs/masers/lib/python3.13/site-packages/ehtim/statistics/dataframes.py:198: FutureWarning: The provided callable <function min at 0x108ab16c0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   vis_avg = vis.groupby(grouping).agg(aggregated).reset_index()
# /Users/galagabits/miniconda3/envs/masers/lib/python3.13/site-packages/ehtim/statistics/dataframes.py:198: FutureWarning: The provided callable <function min at 0x108ab16c0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   vis_avg = vis.groupby(grouping).agg(aggregated).reset_index()
# /Users/galagabits/miniconda3/envs/masers/lib/python3.13/site-packages/ehtim/statistics/dataframes.py:198: FutureWarning: The provided callable <function mean at 0x108ab1f80> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   vis_avg = vis.groupby(grouping).agg(aggregated).reset_index()
# /Users/galagabits/miniconda3/envs/masers/lib/python3.13/site-packages/ehtim/statistics/dataframes.py:198: FutureWarning: The provided callable <function sum at 0x108ab0b80> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   vis_avg = vis.groupby(grouping).agg(aggregated).reset_index()

# %%
ngeht.table

tenna_list = ['AA', 'AP', 'AZ']

ngeht.table[ngeht.table['tele1'].isin(tenna_list) & ngeht.table['tele2'].isin(tenna_list)]
# Out:
#      Baseline Length (m)  Baseline Angle (rad)           SNR tele1 tele2  \
# 0           2.620644e+03              2.725025  12331.675909    AA    AP
# 7           2.606023e+03              2.753991  11917.181399    AA    AP
# 13          2.585356e+03              2.789447  12661.139235    AA    AP
# 22          2.558634e+03              2.835918  11124.927157    AA    AP
# 32          6.432801e+06              2.627073    580.987905    AA    AZ
# 42          2.531523e+03              2.888565   7765.024882    AA    AP
# 45          6.439273e+06              2.625113     52.862893    AP    AZ
# 48          6.659349e+06              2.584020     83.913898    AP    AZ
# 59          6.847722e+06              2.556352    772.232636    AA    AZ
# 60          2.487200e+03              3.009661  12128.961810    AA    AP
# 63          6.845491e+06              2.556192     96.570698    AP    AZ
# 72          2.472663e+03              3.093681  12327.367626    AA    AP
# 73          7.024848e+06              2.537628    876.544435    AA    AZ
# 80          7.022747e+06              2.537442    107.454418    AP    AZ
# 95          2.471315e+03              3.111664  12962.552982    AA    AP
# 97          7.052492e+06              2.535919    883.044345    AA    AZ
# 100         7.050415e+06              2.535728    107.924050    AP    AZ
# 114         7.105414e+06              2.534853    870.635208    AA    AZ
# 116         2.470646e+03             -3.127383  12933.682854    AA    AP
# 122         7.103404e+06              2.534650    107.108718    AP    AZ
# 135         2.471453e+03             -3.109347  12627.213337    AA    AP
# 138         7.120965e+06              2.535673    879.862891    AA    AZ
# 143         7.118980e+06              2.535466    107.113693    AP    AZ
# 156         2.476914e+03             -3.059682  11861.746235    AA    AP
# 160         7.145472e+06              2.541726    852.676679    AA    AZ
# 162         7.143549e+06              2.541507    104.944818    AP    AZ
# 178         2.479989e+03             -3.042072  12363.083032    AA    AP
# 179         7.147626e+06              2.545256    843.067661    AA    AZ
# 185         7.145723e+06              2.545034    106.304277    AP    AZ
# 198         2.489763e+03             -2.999903  11827.621859    AA    AP
# 200         7.138461e+06              2.556887    826.594261    AA    AZ
# 206         7.136598e+06              2.556656    103.118427    AP    AZ
# 219         7.129008e+06              2.562874    800.873032    AA    AZ
# 222         2.494604e+03             -2.983087  12360.290111    AA    AP
# 226         7.127160e+06              2.562639     98.031212    AP    AZ
# 240         2.517845e+03             -2.919088  11536.674934    AA    AP
# 242         7.060826e+06              2.594016    706.182917    AA    AZ
# 249         7.059018e+06              2.593768     89.863533    AP    AZ
# 261         7.036900e+06              2.603616    673.434631    AA    AZ
# 262         2.524393e+03             -2.904023  11009.664992    AA    AP
# 268         7.035101e+06              2.603364     85.897516    AP    AZ
# 282         2.531134e+03             -2.889380  11106.528565    AA    AP
# 284         7.010567e+06              2.613946    644.612035    AA    AZ
# 289         7.008766e+06              2.613693     80.863556    AP    AZ
# 303         2.538017e+03             -2.875171  10685.506074    AA    AP
# 306         6.982010e+06              2.625013    619.515205    AA    AZ
# 311         6.980208e+06              2.624757     78.958970    AP    AZ
# 326         2.544983e+03             -2.861420  10121.337181    AA    AP
# 327         6.951430e+06              2.636821    574.730823    AA    AZ
# 332         6.949633e+06              2.636561     74.442080    AP    AZ
# 346         6.919058e+06              2.649367    525.409434    AA    AZ
# 347         2.551978e+03             -2.848143   9608.749024    AA    AP
# 352         6.917254e+06              2.649107     72.189741    AP    AZ
# 369         2.558948e+03             -2.835348   9178.694185    AA    AP
# 370         6.885114e+06              2.662659    497.825506    AA    AZ
# 375         6.883299e+06              2.662398     67.438171    AP    AZ
# 387         6.849833e+06              2.676698    442.598108    AA    AZ
# 391         2.565837e+03             -2.823051   8578.340503    AA    AP
# 397         6.848015e+06              2.676433     63.876787    AP    AZ
#
#          Time       psi
# 0    1.043056  1.939627
# 7    1.643056  1.968593
# 13   2.201389  2.004049
# 22   2.809722  2.050520
# 32   3.368056  1.841675
# 42   3.412500  2.103166
# 45   3.412500  1.839715
# 48   3.968056  1.798622
# 59   4.534722  1.770954
# 60   4.534722  2.224263
# 63   4.534722  1.770794
# 72   5.251389  2.308283
# 73   5.251389  1.752230
# 80   5.251389  1.752044
# 95   5.401389  2.326266
# 97   5.401389  1.750521
# 100  5.401389  1.750330
# 114  5.768055  1.749454
# 116  5.768055 -3.912781
# 122  5.768055  1.749252
# 135  5.918056 -3.894745
# 138  5.918056  1.750274
# 143  5.918056  1.750068
# 156  6.334723 -3.845080
# 160  6.334723  1.756328
# 162  6.334723  1.756109
# 178  6.484722 -3.827470
# 179  6.484722  1.759858
# 185  6.484722  1.759635
# 198  6.851389 -3.785301
# 200  6.851389  1.771489
# 206  6.851389  1.771258
# 219  7.001389  1.777475
# 222  7.001389 -3.768485
# 226  7.001389  1.777241
# 240  7.601389 -3.704486
# 242  7.601389  1.808618
# 249  7.601389  1.808370
# 261  7.751389  1.818218
# 262  7.751389 -3.689421
# 268  7.751389  1.817966
# 282  7.901389 -3.674778
# 284  7.901389  1.828548
# 289  7.901389  1.828295
# 303  8.051389 -3.660569
# 306  8.051389  1.839615
# 311  8.051389  1.839359
# 326  8.201389 -3.646818
# 327  8.201389  1.851422
# 332  8.201389  1.851162
# 346  8.351389  1.863969
# 347  8.351389 -3.633541
# 352  8.351389  1.863708
# 369  8.501389 -3.620746
# 370  8.501389  1.877261
# 375  8.501389  1.877000
# 387  8.651389  1.891299
# 391  8.651389 -3.608449
# 397  8.651389  1.891035

# %%
#ngeht.select_antennas(tenna_list=['AA', 'AP', 'AZ'])

# %%
ngeht.remove_antennas(tenna_list=['AA'])

# %%
freq1 = 230# GHz
freq2 = 345# GHz

ngeht.thermal_atm.table

# ngeht.thermal_atm.thermal_noise_dualband(,freq1=freq1, freq2=freq2)
# Out:
#      Baseline Length (m)  Baseline Angle (rad)           SNR tele1 tele2  \
# 0           2.620644e+03              2.725025  12331.675909    AA    AP
# 1           5.983218e+06             -0.780192    483.325587    AA    SP
# 2           8.588642e+06             -2.398559   1203.258876    AA    PV
# 3           5.985663e+06             -0.780035     56.843981    AP    SP
# 4           8.587595e+06             -2.398279    141.233092    AP    PV
# ..                   ...                   ...           ...   ...   ...
# 403         9.216243e+06             -0.215924     30.479940    JC    SP
# 404         5.752342e+06             -1.538789     47.682707    JC    LM
# 405         9.592128e+06              0.404471     21.137716    LM    SP
# 406         5.752374e+06              1.602827     70.340861    LM    SM
# 407         9.216379e+06             -0.215922     40.828470    SM    SP
#
#          Time       psi
# 0    1.043056  1.939627
# 1    1.043056 -1.565590
# 2    1.043056 -3.183957
# 3    1.043056 -1.565433
# 4    1.043056 -3.183677
# ..        ...       ...
# 403  8.651389 -1.001322
# 404  8.651389 -2.324187
# 405  8.651389 -0.380928
# 406  8.651389  0.817429
# 407  8.651389 -1.001320
#
# [408 rows x 7 columns]

# %%
ngeht.thermal_atm.generate_rand_atm_delay(7, 0.1, 215, unit='sec')
# Out:
# array([3.09673523e-14, 5.73434037e-14, 1.69637878e-14, 3.67274660e-14,
#        2.13986729e-14, 1.38106716e-14, 1.98477119e-16])

# %%
ngeht.grouped_table_time()

# %%
ngeht.thermal_atm.calculate_atm_error()

# %%
ngeht.thermal_atm.atm_obs_angles
# Out:
# array([[-1.57421178e-04,  2.35125283e-03,  7.55881317e-04, ...,
#         -5.28271926e-04, -1.31435377e-03, -3.09380553e-03],
#        [-1.94118648e-03,  2.57443886e-03, -7.78791998e-04, ...,
#          2.54090783e-04, -5.72100014e-04,  1.19890264e-03],
#        [-1.89565122e-04,  1.31094719e-03, -9.95059585e-04, ...,
#          2.74837460e-03, -2.69493022e-03, -1.31271204e-03],
#        ...,
#        [-1.58724810e-03, -1.79554737e-03,  5.87823004e-04, ...,
#          5.69041101e-04,  1.84716513e-03,  9.01084398e-04],
#        [-4.65848562e-06, -3.42900208e-03, -2.12430584e-03, ...,
#         -8.48411488e-04, -2.56471261e-03,  2.09541782e-03],
#        [ 2.97493131e-03, -1.37633375e-04,  3.07757456e-03, ...,
#         -2.84089267e-03,  8.45417629e-04, -4.28148556e-03]],
#       shape=(25, 500))

# %%
import numpy as np

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=150)

ax.hist(np.std(ngeht.thermal_atm.atm_obs_angles, axis=1), bins=5, color='blue', edgecolor='black', alpha=0.7, label='Thermal Errors')
ax.set_xlabel('Standard Deviation of Observed Angles (mas)')
# Out:
# Text(0.5, 0, 'Standard Deviation of Observed Angles (mas)')

# %%
params = 2.4164853793624266, -0.1188661524727489

freq1 = 230# GHz
freq2 = 345# GHz

ngeht.thermal_atm.calculate_thermal_error(freq1=freq1, freq2=freq2, params=params)

# %%
ngeht.thermal_atm.thermal_errors_coreshifts
# Out:
# array([0.00055381, 0.00052838, 0.0004609 , 0.00041722, 0.00062669,
#        0.00049446, 0.00031019, 0.00119855, 0.00028388, 0.00039264,
#        0.00038718, 0.00035914, 0.00033367, 0.00032983, 0.00034421,
#        0.00031255, 0.00031966, 0.00029382, 0.0002921 , 0.00030341,
#        0.00029754, 0.00030582, 0.00031869, 0.00033389, 0.00034449])

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=150)

ax.hist(ngeht.thermal_atm.thermal_errors_coreshifts, bins=20, color='blue', edgecolor='black', alpha=0.7, label='Thermal Errors')
ax.set_xlabel('Core Shift (mas)')
ax.set_title('Core Shift Errors')
# Out:
# Text(0.5, 1.0, 'Core Shift Errors')

# %% [markdown]
# ### Now for 3 antennas, 4 antennas

# %%
fn = '/Volumes/GalagaResearch/Developer/blackholes/coreshift_practice/coreshift/SR1_3C279_2017_101_hi_hops_netcal_StokesI.uvfits'

ngeht_3tennas = ngeht_predictions.load(uvfits=fn, scans=True)
ngeht_3tennas.load_uvfits()
ngeht_3tennas.select_antennas(tenna_list=['AP', 'AZ', 'JC'])
ngeht_3tennas.grouped_table_time()
ngeht_3tennas.remove_scans_tenna_set(tenna_list=['AP', 'AZ', 'JC'])
ngeht_3tennas.thermal_atm.calculate_atm_error(n_runs=10000)
ngeht_3tennas.thermal_atm.calculate_thermal_error(freq1=freq1, freq2=freq2, params=params)

# four antennas
ngeht_4tennas = ngeht_predictions.load(uvfits=fn, scans=True)
ngeht_4tennas.load_uvfits()
ngeht_4tennas.select_antennas(tenna_list=['AP', 'AZ', 'JC', 'LM'])
ngeht_4tennas.grouped_table_time()
ngeht_4tennas.remove_scans_tenna_set(tenna_list=['AP', 'AZ', 'JC', 'LM'])
ngeht_4tennas.thermal_atm.calculate_atm_error(n_runs=10000)
ngeht_4tennas.thermal_atm.calculate_thermal_error(freq1=freq1, freq2=freq2, params=params)
# Out:
# Loading uvfits:  /Volumes/GalagaResearch/Developer/blackholes/coreshift_practice/coreshift/SR1_3C279_2017_101_hi_hops_netcal_StokesI.uvfits
# no IF in uvfits header!
# POLREP_UVFITS: circ
# Number of uvfits Correlation Products: 4
# No NX table in uvfits!
# /Users/galagabits/miniconda3/envs/masers/lib/python3.13/site-packages/ehtim/statistics/dataframes.py:198: FutureWarning: The provided callable <function min at 0x108ab16c0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   vis_avg = vis.groupby(grouping).agg(aggregated).reset_index()
# /Users/galagabits/miniconda3/envs/masers/lib/python3.13/site-packages/ehtim/statistics/dataframes.py:198: FutureWarning: The provided callable <function min at 0x108ab16c0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   vis_avg = vis.groupby(grouping).agg(aggregated).reset_index()
# /Users/galagabits/miniconda3/envs/masers/lib/python3.13/site-packages/ehtim/statistics/dataframes.py:198: FutureWarning: The provided callable <function mean at 0x108ab1f80> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   vis_avg = vis.groupby(grouping).agg(aggregated).reset_index()
# /Users/galagabits/miniconda3/envs/masers/lib/python3.13/site-packages/ehtim/statistics/dataframes.py:198: FutureWarning: The provided callable <function sum at 0x108ab0b80> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   vis_avg = vis.groupby(grouping).agg(aggregated).reset_index()
# Loading uvfits:  /Volumes/GalagaResearch/Developer/blackholes/coreshift_practice/coreshift/SR1_3C279_2017_101_hi_hops_netcal_StokesI.uvfits
# no IF in uvfits header!
# POLREP_UVFITS: circ
# Number of uvfits Correlation Products: 4
# No NX table in uvfits!
# /Users/galagabits/miniconda3/envs/masers/lib/python3.13/site-packages/ehtim/statistics/dataframes.py:198: FutureWarning: The provided callable <function min at 0x108ab16c0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   vis_avg = vis.groupby(grouping).agg(aggregated).reset_index()
# /Users/galagabits/miniconda3/envs/masers/lib/python3.13/site-packages/ehtim/statistics/dataframes.py:198: FutureWarning: The provided callable <function min at 0x108ab16c0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   vis_avg = vis.groupby(grouping).agg(aggregated).reset_index()
# /Users/galagabits/miniconda3/envs/masers/lib/python3.13/site-packages/ehtim/statistics/dataframes.py:198: FutureWarning: The provided callable <function mean at 0x108ab1f80> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   vis_avg = vis.groupby(grouping).agg(aggregated).reset_index()
# /Users/galagabits/miniconda3/envs/masers/lib/python3.13/site-packages/ehtim/statistics/dataframes.py:198: FutureWarning: The provided callable <function sum at 0x108ab0b80> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   vis_avg = vis.groupby(grouping).agg(aggregated).reset_index()

# %%
np.std(ngeht_4tennas.thermal_atm.atm_obs_angles, axis=1)
# Out:
# array([0.0058174 , 0.00564437, 0.005411  , 0.00525937, 0.0051357 ,
#        0.00507234, 0.00494695, 0.00495454, 0.00485939, 0.0047975 ,
#        0.00488883, 0.00487151, 0.00485471, 0.0048504 , 0.00492889,
#        0.00495997])

# %%
fig, ax = plt.subplots(3,1, figsize=(8, 12), dpi=150)

ax[0].hist(ngeht_3tennas.thermal_atm.thermal_errors_coreshifts, bins=5, color='blue', edgecolor='black', alpha=0.7, label='Thermal Errors')
ax[0].set_title('3 antennas thermal core shift errors')

ax[1].hist(ngeht_4tennas.thermal_atm.thermal_errors_coreshifts, bins=5, color='blue', edgecolor='black', alpha=0.7, label='Thermal Errors')
ax[1].set_title('4 antennas thermal core shift errors')

ax[2].hist(ngeht.thermal_atm.thermal_errors_coreshifts, bins=15, color='blue', edgecolor='black', alpha=0.7, label='Thermal Errors')
ax[2].set_xlabel('Core Shift (mas)')
ax[2].set_title('All antennas thermal core shift errors except AA')

ax[0].set_xlim(0, 0.001)
ax[1].set_xlim(0, 0.001)
ax[2].set_xlim(0, 0.001)
# Out:
# (0.0, 0.001)

# %%
fig, ax = plt.subplots(3,1, figsize=(8, 12), dpi=150)

ax[0].hist(np.std(ngeht_3tennas.thermal_atm.atm_obs_angles, axis=1), bins=5, color='blue', edgecolor='black', alpha=0.7, label='Thermal Errors')
ax[0].set_title('3 antennas atm errors')

ax[1].hist(np.std(ngeht_4tennas.thermal_atm.atm_obs_angles, axis=1), bins=5, color='blue', edgecolor='black', alpha=0.7, label='Thermal Errors')
ax[1].set_title('4 antennas atm errors')

ax[2].hist(np.std(ngeht.thermal_atm.atm_obs_angles, axis=1), bins=5, color='blue', edgecolor='black', alpha=0.7, label='Thermal Errors')
ax[2].set_xlabel('Core Shift (mas)')
ax[2].set_title('All antennas atm errors except AA')

ax[0].set_xlim(0, 0.01)
ax[1].set_xlim(0, 0.01)
ax[2].set_xlim(0, 0.01)
# Out:
# (0.0, 0.01)

# %%
fig, ax = plt.subplots(3,1, figsize=(8, 12), dpi=150)

ax[0].hist(ngeht_3tennas.thermal_atm.thermal_noise_dualband_per_time, bins=20, color='blue', edgecolor='black', alpha=0.7, label='Thermal Errors')
ax[0].set_title('3 antennas thermal core shift errors')

ax[1].hist(ngeht_4tennas.thermal_atm.thermal_noise_dualband_per_time, bins=20, color='blue', edgecolor='black', alpha=0.7, label='Thermal Errors')
ax[1].set_title('4 antennas thermal core shift errors')

ax[2].hist(ngeht.thermal_atm.thermal_noise_dualband_per_time, bins=20, color='blue', edgecolor='black', alpha=0.7, label='Thermal Errors')
ax[2].set_xlabel('Core Shift (mas)')
ax[2].set_title('All antennas thermal core shift errors except AA')

ax[0].set_xlim(0, 0.001)
ax[1].set_xlim(0, 0.001)
ax[2].set_xlim(0, 0.001)
# Out:
# (0.0, 0.001)

# %%
for i in ngeht_3tennas.table_grouped:
    print(i)
# Out:
# (5.251389026641846,     Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 80         7.022747e+06              2.537442  107.454418    AP    AZ
# 82         8.502728e+06              2.090998   36.843337    AP    JC
# 85         3.727649e+06              1.140990  160.787497    AZ    JC
#
#         Time       psi
# 80  5.251389  1.752044
# 82  5.251389  1.305600
# 85  5.251389  0.355592  )
# (5.401388883590698,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 100         7.050415e+06              2.535728  107.924050    AP    AZ
# 103         8.634961e+06              2.086180   36.511872    AP    JC
# 107         3.822079e+06              1.156200  159.392872    AZ    JC
#
#          Time       psi
# 100  5.401389  1.750330
# 103  5.401389  1.300782
# 107  5.401389  0.370802  )
# (5.768055438995361,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 122         7.103404e+06              2.534650  107.108718    AP    AZ
# 124         8.916751e+06              2.077885   38.804841    AP    JC
# 128         4.034207e+06              1.188645  177.372437    AZ    JC
#
#          Time       psi
# 122  5.768055  1.749252
# 124  5.768055  1.292487
# 128  5.768055  0.403246  )
# (5.9180556535720825,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 143         7.118980e+06              2.535466  107.113693    AP    AZ
# 145         9.014442e+06              2.075818   44.710576    AP    JC
# 149         4.112674e+06              1.200230  199.787242    AZ    JC
#
#          Time       psi
# 143  5.918056  1.750068
# 145  5.918056  1.290420
# 149  5.918056  0.414831  )
# (6.334722518920898,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 162         7.143549e+06              2.541507  104.944818    AP    AZ
# 166         9.230219e+06              2.073817   47.511862    AP    JC
# 170         4.303001e+06              1.228125  194.006956    AZ    JC
#
#          Time       psi
# 162  6.334723  1.756109
# 166  6.334723  1.288419
# 170  6.334723  0.442726  )
# (6.484722375869751,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 185         7.145723e+06              2.545034  106.304277    AP    AZ
# 187         9.287476e+06              2.074385   51.265203    AP    JC
# 191         4.361010e+06              1.236809  192.044935    AZ    JC
#
#          Time       psi
# 185  6.484722  1.759635
# 187  6.484722  1.288987
# 191  6.484722  0.451410  )
# (6.851388931274414,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 206         7.136598e+06              2.556656  103.118427    AP    AZ
# 208         9.381208e+06              2.078542   55.301043    AP    JC
# 211         4.478078e+06              1.255441  190.956785    AZ    JC
#
#          Time       psi
# 206  6.851389  1.771258
# 208  6.851389  1.293144
# 211  6.851389  0.470043  )
# (7.001388788223267,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 226         7.127160e+06              2.562639   98.031212    AP    AZ
# 229         9.400569e+06              2.081363   57.301517    AP    JC
# 232         4.515530e+06              1.262100  184.352833    AZ    JC
#
#          Time       psi
# 226  7.001389  1.777241
# 229  7.001389  1.295965
# 232  7.001389  0.476702  )
# (7.601388931274414,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 249         7.059018e+06              2.593768   89.863533    AP    AZ
# 250         9.368635e+06              2.099230   69.488088    AP    JC
# 254         4.602335e+06              1.283865  182.591152    AZ    JC
#
#          Time       psi
# 249  7.601389  1.808370
# 250  7.601389  1.313832
# 254  7.601389  0.498467  )
# (7.751388788223267,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 268         7.035101e+06              2.603364   85.897516    AP    AZ
# 271         9.333785e+06              2.105394   70.166415    AP    JC
# 275         4.607957e+06              1.288195  180.707756    AZ    JC
#
#          Time       psi
# 268  7.751389  1.817966
# 271  7.751389  1.319996
# 275  7.751389  0.502797  )
# (7.901388645172119,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 289         7.008766e+06              2.613693   80.863556    AP    AZ
# 292         9.288488e+06              2.112269   72.658680    AP    JC
# 296         4.607060e+06              1.292112  177.256124    AZ    JC
#
#          Time       psi
# 289  7.901389  1.828295
# 292  7.901389  1.326871
# 296  7.901389  0.506713  )
# (8.051389217376709,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 311         6.980208e+06              2.624757   78.958970    AP    AZ
# 313         9.232941e+06              2.119881   74.310813    AP    JC
# 317         4.599624e+06              1.295625  175.492965    AZ    JC
#
#          Time       psi
# 311  8.051389  1.839359
# 313  8.051389  1.334482
# 317  8.051389  0.510227  )
# (8.201389074325562,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 332         6.949633e+06              2.636561   74.442080    AP    AZ
# 334         9.167381e+06              2.128254   74.526870    AP    JC
# 338         4.585640e+06              1.298743  176.673066    AZ    JC
#
#          Time       psi
# 332  8.201389  1.851162
# 334  8.201389  1.342856
# 338  8.201389  0.513345  )
# (8.351388931274414,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 352         6.917254e+06              2.649107   72.189741    AP    AZ
# 355         9.092078e+06              2.137421   74.554769    AP    JC
# 359         4.565116e+06              1.301470  171.435786    AZ    JC
#
#          Time       psi
# 352  8.351389  1.863708
# 355  8.351389  1.352023
# 359  8.351389  0.516072  )
# (8.501388788223267,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 375         6.883299e+06              2.662398   67.438171    AP    AZ
# 376         9.007328e+06              2.147418   74.725313    AP    JC
# 380         4.538063e+06              1.303810  166.674034    AZ    JC
#
#          Time       psi
# 375  8.501389  1.877000
# 376  8.501389  1.362020
# 380  8.501389  0.518412  )
# (8.65138864517212,      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 396         8.913477e+06              2.158284   76.763392    AP    JC
# 397         6.848015e+06              2.676433   63.876787    AP    AZ
# 401         4.504512e+06              1.305761  166.649986    AZ    JC
#
#          Time       psi
# 396  8.651389  1.372886
# 397  8.651389  1.891035
# 401  8.651389  0.520362  )

# %%
ngeht_4tennas.table
#len(ngeht_4tennas.thermal_atm.thermal_noise_dualband_per_time)
# Out:
#      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 18          4.882264e+06              2.649476   45.488052    AP    LM
# 28          5.055118e+06              2.604034   69.433262    AP    LM
# 36          1.271091e+06             -0.297658  204.428956    AZ    LM
# 45          6.439273e+06              2.625113   52.862893    AP    AZ
# 46          5.201363e+06              2.573343   69.484580    AP    LM
# ..                   ...                   ...         ...   ...   ...
# 396         8.913477e+06              2.158284   76.763392    AP    JC
# 397         6.848015e+06              2.676433   63.876787    AP    AZ
# 400         1.956171e+06             -0.799189  202.536070    AZ    LM
# 401         4.504512e+06              1.305761  166.649986    AZ    JC
# 404         5.752342e+06             -1.538789   47.682707    JC    LM
#
#          Time       psi
# 18   2.201389  1.864078
# 28   2.809722  1.818636
# 36   3.368056 -1.083056
# 45   3.412500  1.839715
# 46   3.412500  1.787945
# ..        ...       ...
# 396  8.651389  1.372886
# 397  8.651389  1.891035
# 400  8.651389 -1.584587
# 401  8.651389  0.520362
# 404  8.651389 -2.324187
#
# [107 rows x 7 columns]

# %%
ngeht_3tennas.table
# Out:
#      Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
# 45          6.439273e+06              2.625113   52.862893    AP    AZ
# 48          6.659349e+06              2.584020   83.913898    AP    AZ
# 63          6.845491e+06              2.556192   96.570698    AP    AZ
# 80          7.022747e+06              2.537442  107.454418    AP    AZ
# 82          8.502728e+06              2.090998   36.843337    AP    JC
# 85          3.727649e+06              1.140990  160.787497    AZ    JC
# 100         7.050415e+06              2.535728  107.924050    AP    AZ
# 103         8.634961e+06              2.086180   36.511872    AP    JC
# 107         3.822079e+06              1.156200  159.392872    AZ    JC
# 122         7.103404e+06              2.534650  107.108718    AP    AZ
# 124         8.916751e+06              2.077885   38.804841    AP    JC
# 128         4.034207e+06              1.188645  177.372437    AZ    JC
# 143         7.118980e+06              2.535466  107.113693    AP    AZ
# 145         9.014442e+06              2.075818   44.710576    AP    JC
# 149         4.112674e+06              1.200230  199.787242    AZ    JC
# 162         7.143549e+06              2.541507  104.944818    AP    AZ
# 166         9.230219e+06              2.073817   47.511862    AP    JC
# 170         4.303001e+06              1.228125  194.006956    AZ    JC
# 185         7.145723e+06              2.545034  106.304277    AP    AZ
# 187         9.287476e+06              2.074385   51.265203    AP    JC
# 191         4.361010e+06              1.236809  192.044935    AZ    JC
# 206         7.136598e+06              2.556656  103.118427    AP    AZ
# 208         9.381208e+06              2.078542   55.301043    AP    JC
# 211         4.478078e+06              1.255441  190.956785    AZ    JC
# 226         7.127160e+06              2.562639   98.031212    AP    AZ
# 229         9.400569e+06              2.081363   57.301517    AP    JC
# 232         4.515530e+06              1.262100  184.352833    AZ    JC
# 249         7.059018e+06              2.593768   89.863533    AP    AZ
# 250         9.368635e+06              2.099230   69.488088    AP    JC
# 254         4.602335e+06              1.283865  182.591152    AZ    JC
# 268         7.035101e+06              2.603364   85.897516    AP    AZ
# 271         9.333785e+06              2.105394   70.166415    AP    JC
# 275         4.607957e+06              1.288195  180.707756    AZ    JC
# 289         7.008766e+06              2.613693   80.863556    AP    AZ
# 292         9.288488e+06              2.112269   72.658680    AP    JC
# 296         4.607060e+06              1.292112  177.256124    AZ    JC
# 311         6.980208e+06              2.624757   78.958970    AP    AZ
# 313         9.232941e+06              2.119881   74.310813    AP    JC
# 317         4.599624e+06              1.295625  175.492965    AZ    JC
# 332         6.949633e+06              2.636561   74.442080    AP    AZ
# 334         9.167381e+06              2.128254   74.526870    AP    JC
# 338         4.585640e+06              1.298743  176.673066    AZ    JC
# 352         6.917254e+06              2.649107   72.189741    AP    AZ
# 355         9.092078e+06              2.137421   74.554769    AP    JC
# 359         4.565116e+06              1.301470  171.435786    AZ    JC
# 375         6.883299e+06              2.662398   67.438171    AP    AZ
# 376         9.007328e+06              2.147418   74.725313    AP    JC
# 380         4.538063e+06              1.303810  166.674034    AZ    JC
# 396         8.913477e+06              2.158284   76.763392    AP    JC
# 397         6.848015e+06              2.676433   63.876787    AP    AZ
# 401         4.504512e+06              1.305761  166.649986    AZ    JC
#
#          Time       psi
# 45   3.412500  1.839715
# 48   3.968056  1.798622
# 63   4.534722  1.770794
# 80   5.251389  1.752044
# 82   5.251389  1.305600
# 85   5.251389  0.355592
# 100  5.401389  1.750330
# 103  5.401389  1.300782
# 107  5.401389  0.370802
# 122  5.768055  1.749252
# 124  5.768055  1.292487
# 128  5.768055  0.403246
# 143  5.918056  1.750068
# 145  5.918056  1.290420
# 149  5.918056  0.414831
# 162  6.334723  1.756109
# 166  6.334723  1.288419
# 170  6.334723  0.442726
# 185  6.484722  1.759635
# 187  6.484722  1.288987
# 191  6.484722  0.451410
# 206  6.851389  1.771258
# 208  6.851389  1.293144
# 211  6.851389  0.470043
# 226  7.001389  1.777241
# 229  7.001389  1.295965
# 232  7.001389  0.476702
# 249  7.601389  1.808370
# 250  7.601389  1.313832
# 254  7.601389  0.498467
# 268  7.751389  1.817966
# 271  7.751389  1.319996
# 275  7.751389  0.502797
# 289  7.901389  1.828295
# 292  7.901389  1.326871
# 296  7.901389  0.506713
# 311  8.051389  1.839359
# 313  8.051389  1.334482
# 317  8.051389  0.510227
# 332  8.201389  1.851162
# 334  8.201389  1.342856
# 338  8.201389  0.513345
# 352  8.351389  1.863708
# 355  8.351389  1.352023
# 359  8.351389  0.516072
# 375  8.501389  1.877000
# 376  8.501389  1.362020
# 380  8.501389  0.518412
# 396  8.651389  1.372886
# 397  8.651389  1.891035
# 401  8.651389  0.520362

# %%
tables = []
for i in ngeht_4tennas.table_grouped:
    tables.append(i[1])

tables_3tennas = []
for i in ngeht_3tennas.table_grouped:
    tables_3tennas.append(i[1])

# %%
tenna_list=['AP', 'AZ', 'JC']

# %%
tables_3tennas[0]['SNR']
# Out:
# 80    107.454418
# 82     36.843337
# 85    160.787497
# Name: SNR, dtype: float64

# %%
tables_3tennas
# Out:
# [    Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  80         7.022747e+06              2.537442  107.454418    AP    AZ
#  82         8.502728e+06              2.090998   36.843337    AP    JC
#  85         3.727649e+06              1.140990  160.787497    AZ    JC
#
#          Time       psi
#  80  5.251389  1.752044
#  82  5.251389  1.305600
#  85  5.251389  0.355592  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  100         7.050415e+06              2.535728  107.924050    AP    AZ
#  103         8.634961e+06              2.086180   36.511872    AP    JC
#  107         3.822079e+06              1.156200  159.392872    AZ    JC
#
#           Time       psi
#  100  5.401389  1.750330
#  103  5.401389  1.300782
#  107  5.401389  0.370802  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  122         7.103404e+06              2.534650  107.108718    AP    AZ
#  124         8.916751e+06              2.077885   38.804841    AP    JC
#  128         4.034207e+06              1.188645  177.372437    AZ    JC
#
#           Time       psi
#  122  5.768055  1.749252
#  124  5.768055  1.292487
#  128  5.768055  0.403246  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  143         7.118980e+06              2.535466  107.113693    AP    AZ
#  145         9.014442e+06              2.075818   44.710576    AP    JC
#  149         4.112674e+06              1.200230  199.787242    AZ    JC
#
#           Time       psi
#  143  5.918056  1.750068
#  145  5.918056  1.290420
#  149  5.918056  0.414831  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  162         7.143549e+06              2.541507  104.944818    AP    AZ
#  166         9.230219e+06              2.073817   47.511862    AP    JC
#  170         4.303001e+06              1.228125  194.006956    AZ    JC
#
#           Time       psi
#  162  6.334723  1.756109
#  166  6.334723  1.288419
#  170  6.334723  0.442726  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  185         7.145723e+06              2.545034  106.304277    AP    AZ
#  187         9.287476e+06              2.074385   51.265203    AP    JC
#  191         4.361010e+06              1.236809  192.044935    AZ    JC
#
#           Time       psi
#  185  6.484722  1.759635
#  187  6.484722  1.288987
#  191  6.484722  0.451410  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  206         7.136598e+06              2.556656  103.118427    AP    AZ
#  208         9.381208e+06              2.078542   55.301043    AP    JC
#  211         4.478078e+06              1.255441  190.956785    AZ    JC
#
#           Time       psi
#  206  6.851389  1.771258
#  208  6.851389  1.293144
#  211  6.851389  0.470043  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  226         7.127160e+06              2.562639   98.031212    AP    AZ
#  229         9.400569e+06              2.081363   57.301517    AP    JC
#  232         4.515530e+06              1.262100  184.352833    AZ    JC
#
#           Time       psi
#  226  7.001389  1.777241
#  229  7.001389  1.295965
#  232  7.001389  0.476702  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  249         7.059018e+06              2.593768   89.863533    AP    AZ
#  250         9.368635e+06              2.099230   69.488088    AP    JC
#  254         4.602335e+06              1.283865  182.591152    AZ    JC
#
#           Time       psi
#  249  7.601389  1.808370
#  250  7.601389  1.313832
#  254  7.601389  0.498467  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  268         7.035101e+06              2.603364   85.897516    AP    AZ
#  271         9.333785e+06              2.105394   70.166415    AP    JC
#  275         4.607957e+06              1.288195  180.707756    AZ    JC
#
#           Time       psi
#  268  7.751389  1.817966
#  271  7.751389  1.319996
#  275  7.751389  0.502797  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  289         7.008766e+06              2.613693   80.863556    AP    AZ
#  292         9.288488e+06              2.112269   72.658680    AP    JC
#  296         4.607060e+06              1.292112  177.256124    AZ    JC
#
#           Time       psi
#  289  7.901389  1.828295
#  292  7.901389  1.326871
#  296  7.901389  0.506713  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  311         6.980208e+06              2.624757   78.958970    AP    AZ
#  313         9.232941e+06              2.119881   74.310813    AP    JC
#  317         4.599624e+06              1.295625  175.492965    AZ    JC
#
#           Time       psi
#  311  8.051389  1.839359
#  313  8.051389  1.334482
#  317  8.051389  0.510227  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  332         6.949633e+06              2.636561   74.442080    AP    AZ
#  334         9.167381e+06              2.128254   74.526870    AP    JC
#  338         4.585640e+06              1.298743  176.673066    AZ    JC
#
#           Time       psi
#  332  8.201389  1.851162
#  334  8.201389  1.342856
#  338  8.201389  0.513345  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  352         6.917254e+06              2.649107   72.189741    AP    AZ
#  355         9.092078e+06              2.137421   74.554769    AP    JC
#  359         4.565116e+06              1.301470  171.435786    AZ    JC
#
#           Time       psi
#  352  8.351389  1.863708
#  355  8.351389  1.352023
#  359  8.351389  0.516072  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  375         6.883299e+06              2.662398   67.438171    AP    AZ
#  376         9.007328e+06              2.147418   74.725313    AP    JC
#  380         4.538063e+06              1.303810  166.674034    AZ    JC
#
#           Time       psi
#  375  8.501389  1.877000
#  376  8.501389  1.362020
#  380  8.501389  0.518412  ,
#       Baseline Length (m)  Baseline Angle (rad)         SNR tele1 tele2  \
#  396         8.913477e+06              2.158284   76.763392    AP    JC
#  397         6.848015e+06              2.676433   63.876787    AP    AZ
#  401         4.504512e+06              1.305761  166.649986    AZ    JC
#
#           Time       psi
#  396  8.651389  1.372886
#  397  8.651389  1.891035
#  401  8.651389  0.520362  ]

# %%
list = ngeht_3tennas.thermal_atm.thermal_noise_dualband(freq1, freq2, tables_3tennas[0]['SNR'], tables_3tennas[0]['SNR'], tables_3tennas[0]['Baseline Length (m)'])
np.sqrt(1/(np.sum((list**(-2)))))
# Out:
# np.float64(0.00017687964510331288)

# %%
len(ngeht_3tennas.thermal_atm.thermal_noise_dualband_per_time)
# Out:
# 16

# %%
ngeht_4tennas

# %%
ngeht_4tennas.thermal_atm.thermal_noise_dualband_per_time
# Out:
# [np.float64(0.00012641268311377644),
#  np.float64(0.0001282625825533336),
#  np.float64(0.00011738330064036973),
#  np.float64(0.00011240878586661306),
#  np.float64(0.00011248430135088614),
#  np.float64(0.00011296890329107745),
#  np.float64(0.00010809235243724608),
#  np.float64(0.00011241347786050522),
#  np.float64(0.00011632272475837251),
#  np.float64(0.00011809406909703975),
#  np.float64(0.00012568589340521298),
#  np.float64(0.00012193682314204474),
#  np.float64(0.0001266133557539009),
#  np.float64(0.0001354827373215434),
#  np.float64(0.00014382440187932593),
#  np.float64(0.00014677209853215293)]

# %%
ngeht_3tennas.thermal_atm.thermal_noise_dualband_per_time
# Out:
# [np.float64(0.00017687964510331288),
#  np.float64(0.00017495676260915943),
#  np.float64(0.0001629007018550247),
#  np.float64(0.0001504631994250678),
#  np.float64(0.0001487837560852665),
#  np.float64(0.00014609592666273776),
#  np.float64(0.00014434193028887917),
#  np.float64(0.00014776676416390608),
#  np.float64(0.00014479113535024373),
#  np.float64(0.0001469610672458879),
#  np.float64(0.0001491790773688926),
#  np.float64(0.00015009082475567925),
#  np.float64(0.0001519834304305605),
#  np.float64(0.00015592591433104917),
#  np.float64(0.00016091926460364125),
#  np.float64(0.00016207213366228052)]

# %%
tenna_set={'AP', 'AZ', 'JC'}

# %%
tenna_list=['AP', 'AZ', 'JC']

# %%
# compare_list = []

# compare_list.append(list(tables_3tennas[9]['tele1']))
# compare_list.append(list(tables_3tennas[9]['tele2']))

# # three_tenna_set_tele1 = set(tables_3tennas[0]['tele1'])
# # three_tenna_set_tele2 = set(tables_3tennas[0]['tele2'])

# %%
ants_is_scan = set(tables_3tennas[9]['tele1']).union(set(tables_3tennas[9]['tele2']))

# %%
scans_with_tenna_set = []

for i,j in enumerate(tables_3tennas):
    ants_is_scan = set(tables_3tennas[i]['tele1']).union(set(tables_3tennas[i]['tele2']))
    if ants_is_scan == set(tenna_list):
        scans_with_tenna_set.append(j)

# %%
len(scans_with_tenna_set), len(tables_3tennas)
# Out:
# (16, 16)

# %%
compare_array = np.array(compare_list).flatten()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 compare_array = np.array(compare_list).flatten()
#
# NameError: name 'compare_list' is not defined

# %%
compare_array
# Out:
# array([], dtype=float64)

# %%
all(ele in set(compare_array) for ele in tenna_list)
# Out:
# False

# %%
tables_3tennas[9]['tele2']
# Out:
# 268    AZ
# 271    JC
# 275    JC
# Name: tele2, dtype: object
